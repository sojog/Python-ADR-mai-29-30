# %%
import pandas as pd

# %%
df = pd.read_csv("recipe.csv", index_col=0)
df.head()
# Out:
#                        name  prepTimeMinutes  cookTimeMinutes  servings  \
# 0  Classic Margherita Pizza               20               15         4
# 1       Vegetarian Stir-Fry               15               20         3
# 2    Chocolate Chip Cookies               15               10        24
# 3     Chicken Alfredo Pasta               15               20         4
# 4       Mango Salsa Chicken               15               25         3
#
#   difficulty   cuisine  caloriesPerServing  rating  reviewCount
# 0       Easy   Italian                 300     4.6           98
# 1     Medium     Asian                 250     4.7           26
# 2       Easy  American                 150     4.9           13
# 3     Medium   Italian                 500     4.9           82
# 4       Easy   Mexican                 380     4.9           63

# %%
df["caloriesPerServing"].sum()
# Out:
# np.int64(14760)

# %%
df["caloriesPerServing"].max()
# Out:
# np.int64(550)

# %%
df[ df["caloriesPerServing"] ==  df["caloriesPerServing"].max()]
# Out:
#                name  prepTimeMinutes  cookTimeMinutes  servings difficulty  \
# 10  Chicken Biryani               30               45         6     Medium
# 17  Korean Bibimbap               30               20         2     Medium
#
#       cuisine  caloriesPerServing  rating  reviewCount
# 10  Pakistani                 550     5.0           32
# 17     Korean                 550     4.9           56

# %%
df[ df["caloriesPerServing"] ==  df["caloriesPerServing"].min()]
# Out:
#                    name  prepTimeMinutes  cookTimeMinutes  servings  \
# 42  Mango Avocado Salsa               10                0         4
#
#    difficulty  cuisine  caloriesPerServing  rating  reviewCount
# 42       Easy  Mexican                  90     4.1           78

# %%
max_calories_df = df[ df["caloriesPerServing"] ==  df["caloriesPerServing"].max()] 
max_calories_df[["name", "caloriesPerServing"]]
# Out:
#                name  caloriesPerServing
# 10  Chicken Biryani                 550
# 17  Korean Bibimbap                 550

# %%
df[df["difficulty"] != "Easy"].count()
# Out:
# name                  20
# prepTimeMinutes       20
# cookTimeMinutes       20
# servings              20
# difficulty            20
# cuisine               20
# caloriesPerServing    20
# rating                20
# reviewCount           20
# dtype: int64

# %%
df.describe()
# Out:
#        prepTimeMinutes  cookTimeMinutes   servings  caloriesPerServing  \
# count        50.000000        50.000000  50.000000           50.000000
# mean         20.100000        16.240000   4.320000          295.200000
# std           8.481071        12.418814   3.254134          116.885431
# min           5.000000         0.000000   1.000000           90.000000
# 25%          15.000000        10.000000   3.000000          205.000000
# 50%          20.000000        15.000000   4.000000          280.000000
# 75%          25.000000        23.750000   4.000000          380.000000
# max          45.000000        45.000000  24.000000          550.000000
#
#           rating  reviewCount
# count  50.000000    50.000000
# mean    4.550000    56.860000
# std     0.250917    30.450368
# min     4.100000     0.000000
# 25%     4.300000    30.500000
# 50%     4.600000    58.500000
# 75%     4.700000    83.750000
# max     5.000000    98.000000

# %%
df.groupby("servings").agg(['count'])
# Out:
#           name prepTimeMinutes cookTimeMinutes difficulty cuisine  \
#          count           count           count      count   count
# servings
# 1            3               3               3          3       3
# 2            6               6               6          6       6
# 3            8               8               8          8       8
# 4           21              21              21         21      21
# 5            1               1               1          1       1
# 6            8               8               8          8       8
# 8            2               2               2          2       2
# 24           1               1               1          1       1
#
#          caloriesPerServing rating reviewCount
#                       count  count       count
# servings
# 1                         3      3           3
# 2                         6      6           6
# 3                         8      8           8
# ...

# %%
df[ df["servings"] == 24 ]
# Out:
#                      name  prepTimeMinutes  cookTimeMinutes  servings  \
# 2  Chocolate Chip Cookies               15               10        24
#
#   difficulty   cuisine  caloriesPerServing  rating  reviewCount
# 2       Easy  American                 150     4.9           13

# %%
df.rename(columns={"prepTimeMinutes":"prepTimeMin"})
# Out:
#                                    name  prepTimeMin  cookTimeMinutes  \
# 0              Classic Margherita Pizza           20               15
# 1                   Vegetarian Stir-Fry           15               20
# 2                Chocolate Chip Cookies           15               10
# 3                 Chicken Alfredo Pasta           15               20
# 4                   Mango Salsa Chicken           15               25
# 5             Quinoa Salad with Avocado           20               15
# 6               Tomato Basil Bruschetta           15               10
# 7            Beef and Broccoli Stir-Fry           20               15
# 8                         Caprese Salad           10                0
# 9                   Shrimp Scampi Pasta           15               20
# 10                      Chicken Biryani           30               45
# 11                       Chicken Karahi           20               30
# ...

# %%
df.head(2)
# Out:
#                        name  prepTimeMinutes  cookTimeMinutes  servings  \
# 0  Classic Margherita Pizza               20               15         4
# 1       Vegetarian Stir-Fry               15               20         3
#
#   difficulty  cuisine  caloriesPerServing  rating  reviewCount
# 0       Easy  Italian                 300     4.6           98
# 1     Medium    Asian                 250     4.7           26

# %%
df.rename(columns={"prepTimeMinutes":"prepTimeMin"}, inplace=True)

# %%
df.head(2)
# Out:
#                        name  prepTimeMin  cookTimeMinutes  servings  \
# 0  Classic Margherita Pizza           20               15         4
# 1       Vegetarian Stir-Fry           15               20         3
#
#   difficulty  cuisine  caloriesPerServing  rating  reviewCount
# 0       Easy  Italian                 300     4.6           98
# 1     Medium    Asian                 250     4.7           26

# %%
df = df.sort_values("caloriesPerServing")

df.head(2)
# Out:
#                        name  prepTimeMin  cookTimeMinutes  servings  \
# 42      Mango Avocado Salsa           10                0         4
# 6   Tomato Basil Bruschetta           15               10         6
#
#    difficulty  cuisine  caloriesPerServing  rating  reviewCount
# 42       Easy  Mexican                  90     4.1           78
# 6        Easy  Italian                 120     4.7           95

# %%
df.head(2)
# Out:
#                        name  prepTimeMin  cookTimeMinutes  servings  \
# 42      Mango Avocado Salsa           10                0         4
# 6   Tomato Basil Bruschetta           15               10         6
#
#    difficulty  cuisine  caloriesPerServing  rating  reviewCount
# 42       Easy  Mexican                  90     4.1           78
# 6        Easy  Italian                 120     4.7           95

# %%
df = df.reset_index(drop=True)

# %%
df.sort_values(["caloriesPerServing", "name"], ascending=(True, True), inplace=True)

# %%
df.head()
# Out:
#                               name  prepTimeMin  cookTimeMinutes  servings  \
# 0              Mango Avocado Salsa           10                0         4
# 2  Brazilian Chocolate Brigadeiros           20               10         8
# 1          Tomato Basil Bruschetta           15               10         6
# 6             Brazilian Caipirinha            5                0         1
# 4               Caprese Bruschetta           15                5         6
#
#   difficulty    cuisine  caloriesPerServing  rating  reviewCount
# 0       Easy    Mexican                  90     4.1           78
# 2       Easy  Brazilian                 120     4.2           65
# 1       Easy    Italian                 120     4.7           95
# 6       Easy  Brazilian                 150     4.4           55
# 4       Easy    Italian                 150     4.2           38
